# %%
import os
from paddleocr import PaddleOCR
import matplotlib.pyplot as plt

# === パラメータ設定 ===
DATASET_DIR = "dataset"
IMAGE_SIZES = [20, 30, 40, 50, 60]
CHARACTER_SETS = ["digit", "alphabet", "hiragana", "katakana", "kanji"]

ocr = PaddleOCR(use_angle_cls=False, lang='japan')

def evaluate_category(category):
    print(f"\n🟦 Evaluating category: {category}")
    results = []

    # ラベル読み込み
    label_path = os.path.join(DATASET_DIR, category, "labels.txt")
    with open(label_path, "r", encoding="utf-8") as f:
        lines = [line.strip().split(" ", 1) for line in f.readlines()]
        label_dict = {path: char for path, char in lines}

    # サイズごとの精度
    for size in IMAGE_SIZES:
        img_dir = os.path.join(DATASET_DIR, category, "images", str(size))
        image_files = [f for f in os.listdir(img_dir) if f.endswith(".png")]
        total = len(image_files)
        correct = 0

        print(f"\n▶ Size {size} px — total {total} images")

        for i, fname in enumerate(image_files, 1):
            img_path = os.path.join(img_dir, fname)
            rel_path = os.path.join("images", str(size), fname)

            gt_text = label_dict.get(rel_path, "")
            pred_text = ""

            result = ocr.ocr(img_path)
            if result and result[0]:
                pred_text = result[0][0][1][0]

            if pred_text == gt_text:
                correct += 1

            # --- 進捗表示 ---
            print(f"  [{i}/{total}] GT: '{gt_text}' | Pred: '{pred_text}' | {'✅' if pred_text == gt_text else '❌'}")

        accuracy = correct / total if total > 0 else 0
        print(f"✅ Accuracy for size {size}px: {accuracy:.3f}")
        results.append(accuracy)

    return results

def plot_results(all_results):
    plt.figure(figsize=(10, 6))
    for category, acc_list in all_results.items():
        plt.plot(IMAGE_SIZES, acc_list, marker="o", label=category)

    plt.xlabel("Image Size (px)")
    plt.ylabel("OCR Accuracy")
    plt.title("OCR Accuracy vs Image Size (by Character Set)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig("ocr_accuracy_vs_size.png")
    plt.show()

if __name__ == "__main__":
    all_results = {}

    for cat in CHARACTER_SETS:
        acc = evaluate_category(cat)
        all_results[cat] = acc

    plot_results(all_results)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_10892\429457741.py:10: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr = PaddleOCR(use_angle_cls=False, lang='japan')
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 579.19it/s]
# Creating model: ('UVDoc', None)
# The model(UVDoc) is not supported to run in MKLDNN mode! Using `paddle` instead!
# Using official model (UVDoc), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 355.92it/s]
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1788.36it/s]
# Creating model: ('PP-OCRv5_server_rec', None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 548.88it/s]
# 🟦 Evaluating category: digit
#
# ▶ Size 20 px — total 100 images
# C:\Users\micha\AppData\Local\Temp\ipykernel_10892\429457741.py:38: DeprecationWarning: Please use `predict` instead.
#   result = ocr.ocr(img_path)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 72
#      69 all_results = {}
#      71 for cat in CHARACTER_SETS:
# ---> 72     acc = evaluate_category(cat)
#      73     all_results[cat] = acc
#      75 plot_results(all_results)
#
# Cell In[3], line 40, in evaluate_category(category)
#      38 result = ocr.ocr(img_path)
#      39 if result and result[0]:
# ---> 40     pred_text = result[0][0][1][0]
#      42 if pred_text == gt_text:
#      43     correct += 1
#
# KeyError: 0

# %%
from paddleocr import PaddleOCR
import os

# OCR 初期化
ocr = PaddleOCR(use_angle_cls=False, lang='japan')

# テスト画像パス（例）
img_path = "dataset/digit/images/30/img_0000.png"  # ← 実際のパスに置き換えて

# OCR 実行
results = ocr.ocr(img_path)

# 結果の表示
for line in results:  # 通常1画像あたり1要素
    for res in line:  # 各テキスト行
        box, (text, conf) = res
        print(f"予測文字: {text}, 信頼度: {conf:.2f}")
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_10892\1347132874.py:5: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr = PaddleOCR(use_angle_cls=False, lang='japan')
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 836.13it/s]
# Creating model: ('UVDoc', None)
# The model(UVDoc) is not supported to run in MKLDNN mode! Using `paddle` instead!
# Using official model (UVDoc), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 548.57it/s]
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 839.14it/s]
# Creating model: ('PP-OCRv5_server_rec', None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 535.67it/s]
# C:\Users\micha\AppData\Local\Temp\ipykernel_10892\1347132874.py:11: DeprecationWarning: Please use `predict` instead.
#   results = ocr.ocr(img_path)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 16
#      14 for line in results:  # 通常1画像あたり1要素
#      15     for res in line:  # 各テキスト行
# ---> 16         box, (text, conf) = res
#      17         print(f"予測文字: {text}, 信頼度: {conf:.2f}")
#
# ValueError: too many values to unpack (expected 2)

# %%
from paddleocr import PaddleOCR
import pprint

ocr = PaddleOCR(use_angle_cls=False, lang='japan')
img_path = "dataset/digit/images/30/img_0000.png"  # ← パスは適宜変更

results = ocr.ocr(img_path)

# 結果の構造を見てみる
pprint.pprint(results)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_10892\480191482.py:4: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr = PaddleOCR(use_angle_cls=False, lang='japan')
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 751.80it/s]
# Creating model: ('UVDoc', None)
# The model(UVDoc) is not supported to run in MKLDNN mode! Using `paddle` instead!
# Using official model (UVDoc), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 526.53it/s]
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 594.88it/s]
# Creating model: ('PP-OCRv5_server_rec', None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in C:\Users\micha\.paddlex\official_models.
# Fetching 6 files: 100%|█████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 538.54it/s]
# C:\Users\micha\AppData\Local\Temp\ipykernel_10892\480191482.py:7: DeprecationWarning: Please use `predict` instead.
#   results = ocr.ocr(img_path)
# [{'doc_preprocessor_res': {'angle': 0,
#                            'input_img': array([[[255, ..., 255],
#         ...,
#         [255, ..., 255]],
#
#        ...,
#
#        [[255, ..., 255],
#         ...,
#         [255, ..., 255]]], shape=(100, 100, 3), dtype=uint8),
#                            'input_path': None,
#                            'model_settings': {'use_doc_orientation_classify': True,
#                                               'use_doc_unwarping': True},
#                            'output_img': array([[[255, ..., 255],
#         ...,
#         [255, ..., 255]],
#
#        ...,
#
#        [[255, ..., 255],
#         ...,
#         [255, ..., 255]]], shape=(100, 100, 3), dtype=uint8),
#                            'page_index': None,
#                            'rot_img': array([[[255, ..., 255],
#         ...,
#         [255, ..., 255]],
#
#        ...,
#
#        [[255, ..., 255],
#         ...,
#         [255, ..., 255]]], shape=(100, 100, 3), dtype=uint8)},
#   'dt_polys': [array([[30, 28],
#        ...,
#        [30, 74]], shape=(4, 2), dtype=int16)],
#   'input_path': 'dataset/digit/images/30/img_0000.png',
#   'model_settings': {'use_doc_preprocessor': True,
#                      'use_textline_orientation': False},
#   'page_index': None,
#   'rec_boxes': array([[30, ..., 74]], shape=(1, 4), dtype=int16),
#   'rec_polys': [array([[30, 28],
#        ...,
#        [30, 74]], shape=(4, 2), dtype=int16)],
#   'rec_scores': [0.993362307548523],
#   'rec_texts': ['0'],
#   'text_det_params': {'box_thresh': 0.6,
#                       'limit_side_len': 64,
#                       'limit_type': 'min',
#                       'max_side_limit': 4000,
#                       'thresh': 0.3,
#                       'unclip_ratio': 1.5},
#   'text_rec_score_thresh': 0.0,
#   'text_type': 'general',
#   'textline_orientation_angles': [-1],
#   'vis_fonts': [<paddlex.utils.fonts.Font object at 0x00000204CD16E540>]}]
